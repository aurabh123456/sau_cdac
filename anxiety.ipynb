# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('anxiety.csv')

# %%
df
# Out:
#              Name  Age  Gender Educational status Religion Mothers education  \
# 0        R Anitha   17  Female           Class 12    Hindu        Illiterate
# 1         Anasuya   17  Female           Class 12    Hindu        Illiterate
# 2       K Sridevi   17  Female           Class 12    Hindu        Illiterate
# 3        S Harish   17    Male           Class 12    Hindu       High school
# 4         Bhavana   17  Female           Class 12    Hindu        Illiterate
# ..            ...  ...     ...                ...      ...               ...
# 145  M Narsimhulu   17    Male           Class 12    Hindu       High school
# 146   Mirza Nawab   17    Male           Class 12   Muslim        Illiterate
# 147  G Naveen kum   17    Male           Class 12    Hindu       High school
# 148  P Vijaya lax   17  Female           Class 12    Hindu        Illiterate
# 149         Padma   17  Female           Class 12    Hindu        Illiterate
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of              Name  Age  Gender Educational status Religion Mothers education  \
# 0        R Anitha   17  Female           Class 12    Hindu        Illiterate
# 1         Anasuya   17  Female           Class 12    Hindu        Illiterate
# 2       K Sridevi   17  Female           Class 12    Hindu        Illiterate
# 3        S Harish   17    Male           Class 12    Hindu       High school
# 4         Bhavana   17  Female           Class 12    Hindu        Illiterate
# ..            ...  ...     ...                ...      ...               ...
# 145  M Narsimhulu   17    Male           Class 12    Hindu       High school
# 146   Mirza Nawab   17    Male           Class 12   Muslim        Illiterate
# 147  G Naveen kum   17    Male           Class 12    Hindu       High school
# 148  P Vijaya lax   17  Female           Class 12    Hindu        Illiterate
# 149         Padma   17  Female           Class 12    Hindu        Illiterate
#
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Educational status', 'Religion',
#        'Mothers education', 'Education of family head',
#        'Occupation of family head', 'Family income',
#        'Socio economic status:  add up score from 7,8,9', 'Place of residence',
#        'Type of family', 'BDI Sum Score', 'Panic Disorder',
#        'Generalized Anxiety Disorder', 'Separation Anxiety',
#        'Social Anxiety Disorder', 'Significant School Avoidance',
#        'Total Scared', 'BDI', 'City of Patient', 'Type of Mobile'],
#       dtype='object')

# %%
df['Separation Anxiety']
# Out:
# 0       3
# 1       7
# 2       6
# 3       0
# 4      12
#        ..
# 145     4
# 146     8
# 147     4
# 148    13
# 149     9
# Name: Separation Anxiety, Length: 150, dtype: int64

# %%
df1=df['Separation Anxiety']

# %%
sns.boxplot(df1)
# Out:
# /home/saurabh/Downloads/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Separation Anxiety'>

# %%
df1
# Out:
# 0       3
# 1       7
# 2       6
# 3       0
# 4      12
#        ..
# 145     4
# 146     8
# 147     4
# 148    13
# 149     9
# Name: Separation Anxiety, Length: 150, dtype: int64

# %%
sns.histplot(df1)
# Out:
# <AxesSubplot:xlabel='Separation Anxiety', ylabel='Count'>
